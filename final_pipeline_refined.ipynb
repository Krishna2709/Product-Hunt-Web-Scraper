# %%
import logging
import pandas as pd
import re
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

logging.basicConfig(level=logging.INFO)


class ProductHuntScraper:
    def __init__(self):
        self.edge_options = Options()
        self.edge_options.add_argument("--headless")
        self.base_url = "https://www.producthunt.com"
        self.unwanted_tags = ['script', 'style', 'button', 'input', 'img', 'video', 'head', 'svg']

    def _get_soup(self, url):
        with webdriver.Edge(options=self.edge_options) as driver:
            driver.get(url)
            scroll_downs = 5
            for _ in range(scroll_downs):
                driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.END)
                time.sleep(2)
            html_content = driver.page_source

        soup = BeautifulSoup(html_content, 'html.parser')
        for tag in self.unwanted_tags:
            for unwanted_tag in soup.find_all(tag):
                unwanted_tag.decompose()
        return soup

    def extract_product_url(self, url):
        soup = self._get_soup(url)
        for link in soup.find_all("a", href=True):
            match = re.match(r'^/products/[^/]+$', link['href'])
            if match:
                return match.group()

    def extract_product_site_url(self, url):
        soup = self._get_soup(url)
        product_webpage_tag = soup.find("a", {"class": "styles_button__7X8Df", "data-test": "product-header-visit-button"})
        if product_webpage_tag:
            product_webpage = product_webpage_tag['href']
            return product_webpage

    @staticmethod
    def clean_url(url):
        cleaned = re.sub(r'^https?://', '', url)
        cleaned = re.sub(r'\?.*$', '', cleaned)
        return cleaned

    def get_product_details(self, url):
        soup = self._get_soup(url)
        about_content = soup.find(id="about")
        data = about_content.text

        product_details = {
            'followers': re.search(r'(\d+(\.\d+)?[Kk]?)followers', data).group(1),
            'created_by': re.search(r'Made by (.+?)\.', data).group(1).split(", ")[:-1] + re.search(r'Made by (.+?)\.', data).group(1).split(" and ")[-1:],
            'upvotes': int(re.search(r'Upvotes([\d,]+)', data).group(1).replace(',', '')),
            'comments': int(re.search(r'Comments(\d+)', data).group(1))
        }
        return product_details

    def get_latest_product_details(self):
        soup = self._get_soup(self.base_url)
        products, product_descriptions, page_urls, created_by, followers, upvotes, comments, product_urls, product_webpage_urls = ([] for _ in range(9))

        section = soup.find('div', attrs={'data-test': 'homepage-section-0'})
        if section:
            for i, item in enumerate(section.find_all("div", class_="styles_item__Dk_nz")):
                product_name_tag = item.find("a", class_="styles_title__HzPeb")
                product_description_tag = item.find("a", class_="styles_tagline__Dwvza")
                
                if product_name_tag and product_description_tag:
                    products.append(product_name_tag.text.strip())
                    product_descriptions.append(product_description_tag.text.strip())
                    page_urls.append(product_name_tag['href'])

                    product_details = self.get_product_details(self.base_url + product_name_tag['href'])
                    created_by.append(product_details['created_by'])
                    followers.append(product_details['followers'])
                    upvotes.append(product_details['upvotes'])
                    comments.append(product_details['comments'])

                    product_page_url = self.extract_product_url(self.base_url + product_name_tag['href'])
                    product_urls.append(product_page_url)
                    product_webpage_urls.append(self.extract_product_site_url(self.base_url + product_page_url))

        cleaned_urls = [self.clean_url(url) for url in product_webpage_urls]

        df = pd.DataFrame({
            'Product': products,
            'Product Description': product_descriptions,
            'Website': cleaned_urls,
            'Created By': created_by,
            'Followers': followers,
            'Upvotes': upvotes,
            'Comments': comments
        })

        return df

# %%
scraper = ProductHuntScraper()

start = time.perf_counter()
df = scraper.get_latest_product_details()
finish = time.perf_counter()

print(f"\nFinished in {round(finish - start, 2)} second(s)")
# Out:
# Scraping Product Hunt...
#
# Soup Created!!!...
#
#
# Scraping homepage-section-0...
#
#
# Scraping item:  0
#
# Extracting product url:  https://www.producthunt.com/posts/fedica
#
# Extracting product site url:  https://www.producthunt.com/products/fedica
#
# Product site url:  https://fedica.com?ref=producthunt
#
# Scraping item:  1
#
# Extracting product url:  https://www.producthunt.com/posts/freelogo-dev
#
# Extracting product site url:  https://www.producthunt.com/products/freelogo-dev
#
# Product site url:  https://www.freelogo.dev?ref=producthunt
#
# Scraping item:  2
#
# Extracting product url:  https://www.producthunt.com/posts/salesos-with-ai-customer-persona
#
# Extracting product site url:  https://www.producthunt.com/products/salesos-startos-sales-marketing-system
#
# Product site url:  https://ajinkyabhat.com/salesos?ref=producthunt
#
# Scraping item:  3
#
# Extracting product url:  https://www.producthunt.com/posts/ultimate-etsy-guide-for-digital-products
#
# Extracting product site url:  https://www.producthunt.com/products/ultimate-etsy-guide-for-digital-products
#
# Product site url:  https://jordilabs.gumroad.com/l/utimate-etsy-guide?_gl=1*1e67z73*_ga*MTEyMTQxNTU1OS4xNjg2MzMzMjE4*_ga_6LJN6D94N6*MTY5MzgwOTAwMi4zNjEuMS4xNjkzODEwMjczLjAuMC4w&ref=producthunt
#
# Scraping item:  4
#
# Extracting product url:  https://www.producthunt.com/posts/chatgpt-prompts-for-ai
#
# Extracting product site url:  https://www.producthunt.com/products/chatgpt-prompts-for-ai
#
# Product site url:  https://davidecamera.gumroad.com/l/ChatGPT_AI?ref=producthunt
#
# Scraping item:  5
#
# Extracting product url:  https://www.producthunt.com/posts/playcss
#
# Extracting product site url:  https://www.producthunt.com/products/playcss
#
# Product site url:  https://playcss.app?ref=producthunt
#
# Scraping item:  6
#
# Extracting product url:  https://www.producthunt.com/posts/meal-planner-2
#
# Extracting product site url:  https://www.producthunt.com/products/meal-planner-with-calories-tracker
#
# Product site url:  https://heykelseys.gumroad.com/l/Book?ref=producthunt
#
# Scraping item:  7
#
# Extracting product url:  https://www.producthunt.com/posts/petsitter-kit
#
# Extracting product site url:  https://www.producthunt.com/products/petsitter-kit
#
# Product site url:  https://www.laiew.com/petsitter?ref=producthunt
#
# Scraping item:  8
#
# Extracting product url:  https://www.producthunt.com/posts/habitscore
#
# Extracting product site url:  https://www.producthunt.com/products/habitscore
#
# Product site url:  https://apps.apple.com/us/app/habitscore-habit-tracker/id6464159989?ref=producthunt
#
# Scraping item:  9
#
# Extracting product url:  https://www.producthunt.com/posts/u-eyes
#
# Extracting product site url:  https://www.producthunt.com/products/u-eyes
#
# Product site url:  https://eyeballer.dev?ref=producthunt
#
# Scraping item:  10
#
# Extracting product url:  https://www.producthunt.com/posts/foooood
#
# Extracting product site url:  https://www.producthunt.com/products/foooood
#
# Product site url:  https://s.imagica.ai/e/HIssWjS5UCb?ref=producthunt
#
# Scraping item:  11
#
# Extracting product url:  https://www.producthunt.com/posts/atomiclanguage
#
# Extracting product site url:  https://www.producthunt.com/products/atomiclanguage
#
# Product site url:  https://atomiclanguage.co?ref=producthunt
#
# Scraping item:  12
#
# Extracting product url:  https://www.producthunt.com/posts/draftonn
#
# Extracting product site url:  https://www.producthunt.com/products/draftonn
#
# Product site url:  https://opencollective.com/draftonn?ref=producthunt
#
# Scraping item:  13
#
# Extracting product url:  https://www.producthunt.com/posts/messageme-2
#
# Extracting product site url:  https://www.producthunt.com/products/messageme-2
#
# Product site url:  https://messageme.in?ref=producthunt
#
# Scraping item:  14
#
# Extracting product url:  https://www.producthunt.com/posts/feedbackcorner
#
# Extracting product site url:  https://www.producthunt.com/products/feedbackcorner
#
# Product site url:  https://www.feedbackcorner.com?ref=producthunt
#
# Scraping item:  15
#
# Extracting product url:  https://www.producthunt.com/posts/readonly
#
# Extracting product site url:  https://www.producthunt.com/products/readonly
#
# Product site url:  https://apps.apple.com/ca/app/%E5%8F%AA%E8%AF%BB-%E7%A8%8D%E5%90%8E%E9%98%85%E8%AF%BB/id6452241434?ref=producthunt
#
# Scraping item:  16
#
# Extracting product url:  https://www.producthunt.com/posts/listene
#
# Extracting product site url:  https://www.producthunt.com/products/listene
#
# Product site url:  https://listene.day?ref=producthunt
#
# Scraping item:  17
#
# Extracting product url:  https://www.producthunt.com/posts/electric-vehicle-tax-credit-calculator
#
# Extracting product site url:  https://www.producthunt.com/products/electric-vehicle-tax-credit-calculator
#
# Product site url:  https://www.findthebestcarprice.com/ev-tax-credit?ref=producthunt
#
# Scraping item:  18
#
# Extracting product url:  https://www.producthunt.com/posts/the-supreme-crm
#
# Extracting product site url:  https://www.producthunt.com/products/the-supreme-crm
#
# Product site url:  https://efficiora.gumroad.com/l/supremecrm?ref=producthunt
#
# Scraping item:  19
#
# Extracting product url:  https://www.producthunt.com/posts/personality-archetype-test-for-notion
#
# Extracting product site url:  https://www.producthunt.com/products/personality-archetype-test-for-notion
#
# Product site url:  https://philippstelzel.gumroad.com/l/personality-archetypes?ref=producthunt
#
# Scraping item:  20
#
# Extracting product url:  https://www.producthunt.com/posts/notion-gym-and-nutrition-tracker
#
# Extracting product site url:  https://www.producthunt.com/products/notion-gym-and-nutrition-tracker
#
# Product site url:  https://vairusstrategy.gumroad.com/l/Gym-tracker?ref=producthunt
#
# Scraping item:  21
#
# Extracting product url:  https://www.producthunt.com/posts/webbrevity-ai
#
# Extracting product site url:  https://www.producthunt.com/products/webbrevity-ai
#
# Product site url:  https://web-brevity-ai.vercel.app?ref=producthunt
#
# Scraping item:  22
#
# Extracting product url:  https://www.producthunt.com/posts/100-javascript-snippets-for-beginners
#
# Extracting product site url:  https://www.producthunt.com/products/100-javascript-snippets-for-beginners
#
# Product site url:  https://1amitarora.gumroad.com/l/nhboh?utm_source=producthunt&utm_medium=product_launch&utm_campaign=100+%20JavaScript%20Snippets%20for%20Beginners&ref=producthunt
#
# Scraping item:  23
#
# Extracting product url:  https://www.producthunt.com/posts/vokabeln-io
#
# Extracting product site url:  https://www.producthunt.com/products/vokabeln-io
#
# Product site url:  https://vokabeln.io?ref=producthunt
#
# Scraping item:  24
#
# Extracting product url:  https://www.producthunt.com/posts/pin-genie
#
# Extracting product site url:  https://www.producthunt.com/products/pin-genie
#
# Product site url:  https://pingenie.co.uk?ref=producthunt
#
# Scraping item:  25
#
# Extracting product url:  https://www.producthunt.com/posts/ichatbook
#
# Extracting product site url:  https://www.producthunt.com/products/ichatbook
#
# Product site url:  https://ichatbook.com?ref=producthunt
#
# Page URLS...
#  ['/posts/fedica', '/posts/freelogo-dev', '/posts/salesos-with-ai-customer-persona', '/posts/ultimate-etsy-guide-for-digital-products', '/posts/chatgpt-prompts-for-ai', '/posts/playcss', '/posts/meal-planner-2', '/posts/petsitter-kit', '/posts/habitscore', '/posts/u-eyes', '/posts/foooood', '/posts/atomiclanguage', '/posts/draftonn', '/posts/messageme-2', '/posts/feedbackcorner', '/posts/readonly', '/posts/listene', '/posts/electric-vehicle-tax-credit-calculator', '/posts/the-supreme-crm', '/posts/personality-archetype-test-for-notion', '/posts/notion-gym-and-nutrition-tracker', '/posts/webbrevity-ai', '/posts/100-javascript-snippets-for-beginners', '/posts/vokabeln-io', '/posts/pin-genie', '/posts/ichatbook']
#
# Product Webpage URLS...
#  ['https://fedica.com?ref=producthunt', 'https://www.freelogo.dev?ref=producthunt', 'https://ajinkyabhat.com/salesos?ref=producthunt', 'https://jordilabs.gumroad.com/l/utimate-etsy-guide?_gl=1*1e67z73*_ga*MTEyMTQxNTU1OS4xNjg2MzMzMjE4*_ga_6LJN6D94N6*MTY5MzgwOTAwMi4zNjEuMS4xNjkzODEwMjczLjAuMC4w&ref=producthunt', 'https://davidecamera.gumroad.com/l/ChatGPT_AI?ref=producthunt', 'https://playcss.app?ref=producthunt', 'https://heykelseys.gumroad.com/l/Book?ref=producthunt', 'https://www.laiew.com/petsitter?ref=producthunt', 'https://apps.apple.com/us/app/habitscore-habit-tracker/id6464159989?ref=producthunt', 'https://eyeballer.dev?ref=producthunt', 'https://s.imagica.ai/e/HIssWjS5UCb?ref=producthunt', 'https://atomiclanguage.co?ref=producthunt', 'https://opencollective.com/draftonn?ref=producthunt', 'https://messageme.in?ref=producthunt', 'https://www.feedbackcorner.com?ref=producthunt', 'https://apps.apple.com/ca/app/%E5%8F%AA%E8%AF%BB-%E7%A8%8D%E5%90%8E%E9%98%85%E8%AF%BB/id6452241434?ref=producthunt', 'https://listene.day?ref=producthunt', 'https://www.findthebestcarprice.com/ev-tax-credit?ref=producthunt', 'https://efficiora.gumroad.com/l/supremecrm?ref=producthunt', 'https://philippstelzel.gumroad.com/l/personality-archetypes?ref=producthunt', 'https://vairusstrategy.gumroad.com/l/Gym-tracker?ref=producthunt', 'https://web-brevity-ai.vercel.app?ref=producthunt', 'https://1amitarora.gumroad.com/l/nhboh?utm_source=producthunt&utm_medium=product_launch&utm_campaign=100+%20JavaScript%20Snippets%20for%20Beginners&ref=producthunt', 'https://vokabeln.io?ref=producthunt', 'https://pingenie.co.uk?ref=producthunt', 'https://ichatbook.com?ref=producthunt']
#
# Cleaning urls...
#
#
# Cleaning url...
#  https://fedica.com?ref=producthunt
#
# Cleaning url...
#  https://www.freelogo.dev?ref=producthunt
#
# Cleaning url...
#  https://ajinkyabhat.com/salesos?ref=producthunt
#
# Cleaning url...
#  https://jordilabs.gumroad.com/l/utimate-etsy-guide?_gl=1*1e67z73*_ga*MTEyMTQxNTU1OS4xNjg2MzMzMjE4*_ga_6LJN6D94N6*MTY5MzgwOTAwMi4zNjEuMS4xNjkzODEwMjczLjAuMC4w&ref=producthunt
#
# Cleaning url...
#  https://davidecamera.gumroad.com/l/ChatGPT_AI?ref=producthunt
#
# Cleaning url...
#  https://playcss.app?ref=producthunt
#
# Cleaning url...
#  https://heykelseys.gumroad.com/l/Book?ref=producthunt
#
# Cleaning url...
#  https://www.laiew.com/petsitter?ref=producthunt
#
# Cleaning url...
#  https://apps.apple.com/us/app/habitscore-habit-tracker/id6464159989?ref=producthunt
#
# Cleaning url...
#  https://eyeballer.dev?ref=producthunt
#
# Cleaning url...
#  https://s.imagica.ai/e/HIssWjS5UCb?ref=producthunt
#
# Cleaning url...
#  https://atomiclanguage.co?ref=producthunt
#
# Cleaning url...
#  https://opencollective.com/draftonn?ref=producthunt
#
# Cleaning url...
#  https://messageme.in?ref=producthunt
#
# Cleaning url...
#  https://www.feedbackcorner.com?ref=producthunt
#
# Cleaning url...
#  https://apps.apple.com/ca/app/%E5%8F%AA%E8%AF%BB-%E7%A8%8D%E5%90%8E%E9%98%85%E8%AF%BB/id6452241434?ref=producthunt
#
# Cleaning url...
#  https://listene.day?ref=producthunt
#
# Cleaning url...
#  https://www.findthebestcarprice.com/ev-tax-credit?ref=producthunt
#
# Cleaning url...
#  https://efficiora.gumroad.com/l/supremecrm?ref=producthunt
#
# Cleaning url...
#  https://philippstelzel.gumroad.com/l/personality-archetypes?ref=producthunt
#
# Cleaning url...
#  https://vairusstrategy.gumroad.com/l/Gym-tracker?ref=producthunt
#
# Cleaning url...
#  https://web-brevity-ai.vercel.app?ref=producthunt
#
# Cleaning url...
#  https://1amitarora.gumroad.com/l/nhboh?utm_source=producthunt&utm_medium=product_launch&utm_campaign=100+%20JavaScript%20Snippets%20for%20Beginners&ref=producthunt
#
# Cleaning url...
#  https://vokabeln.io?ref=producthunt
#
# Cleaning url...
#  https://pingenie.co.uk?ref=producthunt
#
# Cleaning url...
#  https://ichatbook.com?ref=producthunt
#
# Creating dataframe...
#
#
# Finished in 777.81 second(s)

# %%
df
# Out:
#                                      Product  \
# 0                                     Fedica
# 1                               FreeLogo.dev
# 2           SalesOS with AI Customer Persona
# 3   Ultimate Etsy Guide for Digital Products
# 4                     ChatGPT Prompts for AI
# 5                                    playCSS
# 6                               Meal Planner
# 7                              PetSitter Kit
# 8                                 HabitScore
# 9                                     U-Eyes
# 10                                   FOOOOOD
# 11                            AtomicLanguage
# 12                                  DraftOnn
# 13                                MessageMe™
# 14                            FeedbackCorner
# 15                                  Readonly
# 16                                   Listene
# 17    Electric Vehicle Tax Credit Calculator
# 18                           The Supreme CRM
# 19     Personality Archetype Test for Notion
# 20          Notion Gym and Nutrition Tracker
# 21                             WebBrevity.AI
# 22    100+ Javascript Snippets for Beginners
# 23                               Vokabeln.io
# 24                                 Pin Genie
# 25                                 iChatBook
#
#                                   Product Description  \
# 0                  The one AI social media powerhouse
# 1     Free logo generator, no bullshit, takes seconds
# 2   Nail your target customer and fix your sales f...
# 3                Etsy success: your complete handbook
# 4                    Use ChatGPT to become an AI guru
# 5   Improve your CSS skills by playing daily chall...
# 6   Automatically track your calories and plan hea...
# 7                Streamline pet care business success
# 8           Focus on your habits, not on your streaks
# 9   A Chrome Extension for simulating and capture ...
# 10                                     Done with ease
# 11  Habitual language learning - one sentence at a...
# 12  The next-gen minimalist note-taking app for st...
# 13  Consent messaging platform for critical commun...
# 14       Instant feedback, real Insights, zero hassle
# 15         A simple and easy to use read it later app
# 16                  Daily English listening exercises
# 17  Determine your federal and state savings when ...
# 18  Master your customer relationships with unmatc...
# 19  Unlock the secrets of personality, inspired by...
# 20  Let Notion organize your workouts, meals & you...
# 21  Get the summarized text of blog/article on int...
# 22  Javascript snippets that can make your coding ...
# 23          Learn German with AI generated flashcards
# 24  Create entertaining podcasts from any word doc...
# 25   Binge books, boost reading & accelerate learning
#
#                                               Website  \
# 0                                          fedica.com
# 1                                    www.freelogo.dev
# 2                             ajinkyabhat.com/salesos
# 3          jordilabs.gumroad.com/l/utimate-etsy-guide
# 4               davidecamera.gumroad.com/l/ChatGPT_AI
# 5                                         playcss.app
# 6                       heykelseys.gumroad.com/l/Book
# 7                             www.laiew.com/petsitter
# 8   apps.apple.com/us/app/habitscore-habit-tracker...
# 9                                       eyeballer.dev
# 10                         s.imagica.ai/e/HIssWjS5UCb
# 11                                  atomiclanguage.co
# 12                        opencollective.com/draftonn
# 13                                       messageme.in
# 14                             www.feedbackcorner.com
# 15  apps.apple.com/ca/app/%E5%8F%AA%E8%AF%BB-%E7%A...
# 16                                        listene.day
# 17          www.findthebestcarprice.com/ev-tax-credit
# 18                 efficiora.gumroad.com/l/supremecrm
# 19  philippstelzel.gumroad.com/l/personality-arche...
# 20           vairusstrategy.gumroad.com/l/Gym-tracker
# 21                          web-brevity-ai.vercel.app
# 22                     1amitarora.gumroad.com/l/nhboh
# 23                                        vokabeln.io
# 24                                     pingenie.co.uk
# 25                                      ichatbook.com
#
#                                            Created By Followers  Upvotes  \
# 0   [Samir Al-Battran, Erin Heywood, Dmitry Ustime...       775      544
# 1                [Miłosz Jankiewicz, Łukasz Cybulski]       271      253
# 2                  [Ajinkya Bhat | Notion X Startups]       256      211
# 3                                   [Jordi Rodriguez]       202      180
# 4                                     [Davide Camera]       215      167
# 5                                         [Frank Eno]       145      143
# 6                                          [Kelsey S]       115      118
# 7                                               [leo]       119      108
# 8                                        [Sven Navez]        91       92
# 9                                          [Han Tran]        82       84
# 10                                    [Abhishek Jha ]        89       83
# 11                                        [Sebastian]        83       83
# 12                                       [RangerDevv]        72       76
# 13                                 [KANAK KAWADIWALE]        74       74
# 14                                  [Philipp Buerger]        62       64
# 15                                       [Brook Chen]        58       59
# 16                                   [Kevin Hermawan]        56       56
# 17                                       [Geoff Cudd]        54       55
# 18                                            [Tyson]        63       48
# 19                                  [Philipp Stelzel]        81       49
# 20                                        [El Vairus]        45       47
# 21                          [Charandeep Singh Chawla]        45       40
# 22                                       [Amit Arora]        47       37
# 23                                       [Petr Kubes]        40       40
# 24                                     [Phillip Kidd]        37       38
# 25                                       [Brian Yang]       117       36
#
#     Comments
# 0        167
# 1         56
# 2         82
# 3         70
# 4         29
# 5         33
# 6         39
# 7         26
# 8         11
# 9          9
# 10        19
# 11        14
# 12         6
# 13         5
# 14         6
# 15         5
# 16        12
# 17         5
# 18         4
# 19         5
# 20         8
# 21         9
# 22         3
# 23         4
# 24        17
# 25         9

# %%
ph_df = pd.read_csv("../datasets/producthunt_company_details.csv")
# Out:
#        Product                                Product Description  \
# 0    Heyscribe  Manage and monetize your creative work-in-process
# 1   ◯˚GitStart                         Pull requests as a service
# 2      myReach  Your second brain, powered by AI – ChatGPT for...
# 3  dyrector.io       Open-source SelfOps platform for containers.
# 4      X2Image                   Convert tweets to stylish images
#
#               Website                                         Created By  \
# 0       heyscribe.com             ['Artem Samarsky', 'Anastasia Morgan']
# 1        gitstart.com  ['Edward So', 'Miracle Ogunlade', 'Emily Luo',...
# 2          myreach.io  ['Christopher Payne', 'Alex Calle', 'Agnes Fel...
# 3  app.dyrectorio.com                                  ['Orbán Levente']
# 4         x2image.app                                     ['Ömer Taban']
#
#   Followers  Upvotes  Comments
# 0       447      392       136
# 1       310      292        60
# 2       229      214        66
# 3       296      160        43
# 4       157      157        61

# %%
updated_df = pd.concat([df, ph_df], ignore_index=True)

# %%
updated_df.shape, ph_df.shape, df.shape
# Out:
# ((159, 7), (133, 7), (26, 7))

# %%
updated_df.to_csv("../datasets/producthunt_company_details.csv", index=False)
